# %% [markdown]
# <a href="https://www.kaggle.com/code/benzilla987/codewarschallenge-stringendswith-090223?scriptVersionId=141772149" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# Complete the solution so that it returns true if the first argument(string) passed in ends with the 2nd argument (also a string).
#
# Examples:
#
# solution('abc', 'bc') # returns true
# solution('abc', 'd') # returns false

# %%
def solution(text, ending):
    x=len(ending)
    x=x
    if text[-x:]==ending:
        return True
    else:
        return False

# %% [markdown]
# # Notes
#
# Quick one today. It's Saturday and a day off for me, but I wanted to just take a moment to write a little bit of code. The top solution on this one is below. They did it in a single line of code using the endswith() function, which I was unaware of. This is a really helpful argument that I'll keep in mind for future use. Happy Saturday!
#
# `def solution(string, ending):
#     return string.endswith(ending)`
