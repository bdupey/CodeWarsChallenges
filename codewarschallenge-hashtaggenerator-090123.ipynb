# %% [markdown]
# <a href="https://www.kaggle.com/code/benzilla987/codewarschallenge-hashtaggenerator-090123?scriptVersionId=141679481" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Instructions
#
# The marketing team is spending way too much time typing in hashtags.
# Let's help them with our own Hashtag Generator!
#
# Here's the deal:
#
# It must start with a hashtag (#).
# All words must have their first letter capitalized.
# If the final result is longer than 140 chars it must return false.
# If the input or the result is an empty string it must return false.
# Examples
# " Hello there thanks for trying my Kata"  =>  "#HelloThereThanksForTryingMyKata"
# "    Hello     World   "                  =>  "#HelloWorld"
# ""                                        =>  false

# %%
import re
def generate_hashtag(s):
    hash="#"
    if len(s)==0:
        return False
    else:
        s=s.strip()
        s=re.sub(' +', ' ',s)
        s=s.lower()
        s=s.title()
        s=s.replace(' ','')
        hash+=s
        if len(hash)<141:
            return hash
        else:
            return False

# %% [markdown]
# # Thoughts
#
# Well, someone did this is 5 lines and mine is 16 lines. Theirs also didn't utilize any libraries.
# So it's definitely good to see how someone can write this more effectively. Their solution is
# below. I like how they wrote a quick loop that  split the string and capitalized the first letter.
# I was unaware of the capitalize() method, that converts the first character of a string to an uppercase letter and all other alphabets to lowercase. That's really cool and something to
# keep in my back pocket if I ever need it.
#
#
# Top solution:
#
#         def generate_hashtag(s):
#             output = "#"
#
#             for word in s.split():
#                 output += word.capitalize()
#
#             return False if (len(s) == 0 or len(output) > 140) else outputdef generate_hashtag(s):
#             output = "#"
#
#             for word in s.split():
#                 output += word.capitalize()
#
#             return False if (len(s) == 0 or len(output) > 140) else output
